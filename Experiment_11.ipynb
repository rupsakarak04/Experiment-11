# %%
# Name: Rupsa Karak    PRN: 25070123098
# Experiment 11
# Aim: To create Dataset and load dataset in Pandas library

# %%
#Dataset Creation
import pandas as pd
data = { "Rollno": [98,99,100,101,102], "Gender": ["Female", "Female", "Male", "Male", "Female"], "Department": ["ENTC", "CSE", "IT", "ECE", "CSE"], "CGPA": [9.5, 8.7, 9, 8.23, 8.6]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Rollno  Gender Department  CGPA
# 0      98  Female       ENTC  9.50
# 1      99  Female        CSE  8.70
# 2     100    Male         IT  9.00
# 3     101    Male        ECE  8.23
# 4     102  Female        CSE  8.60

# %%
df.to_csv("dataset.csv", index=False)
print(df)
# Out:
#    Rollno  Gender Department  CGPA
# 0      98  Female       ENTC  9.50
# 1      99  Female        CSE  8.70
# 2     100    Male         IT  9.00
# 3     101    Male        ECE  8.23
# 4     102  Female        CSE  8.60

# %%
df.shape
# Out:
# (5, 4)

# %%
df.size
# Out:
# 20

# %%
df.info() #gives storage, class, datatype, column and other information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rollno      5 non-null      int64
#  1   Gender      5 non-null      object
#  2   Department  5 non-null      object
#  3   CGPA        5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe() #does statistical analysis of the given data. 25%,50% and 75% are called quartile.
# Out:
#            Rollno      CGPA
# count    5.000000  5.000000
# mean   100.000000  8.806000
# std      1.581139  0.475584
# min     98.000000  8.230000
# 25%     99.000000  8.600000
# 50%    100.000000  8.700000
# 75%    101.000000  9.000000
# max    102.000000  9.500000

# %%
# Upload the Dataset
import pandas as pd
import numpy as np
df = pd.read_csv('/content/Cars93.csv')
display(df)
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25                 NaN
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...

# %%
df.shape
# Out:
# (93, 10)

# %%
df.size
# Out:
# 930

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         59 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 7.4+ KB

# %%
df.describe()
# Out:
#            Price   MPG.city  Horsepower  Passengers  Rear.seat.room  \
# count  93.000000  93.000000   93.000000   93.000000       91.000000
# mean   19.509677  22.365591  143.827957    5.086022       27.829670
# std     9.659430   5.619812   52.374410    1.038979        2.989072
# min     7.400000  15.000000   55.000000    2.000000       19.000000
# 25%    12.200000  18.000000  103.000000    4.000000       26.000000
# 50%    17.700000  21.000000  140.000000    5.000000       27.500000
# 75%    23.300000  25.000000  170.000000    6.000000       30.000000
# max    61.900000  46.000000  300.000000    8.000000       36.000000
#
#        Luggage.room
# count     82.000000
# mean      13.890244
# std        2.997967
# min        6.000000
# 25%       12.000000
# 50%       14.000000
# 75%       15.000000
# max       22.000000

# %%
df.head() #gives you data of first 5 rows
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25                 NaN
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
df.tail()  #gives you data of last 5 rows
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 88         109           7            34.0           NaN
# 89         134           5            31.5          14.0
# 90         178           4            26.0          15.0
# 91         114           5            29.5          14.0
# 92         168           5            30.0          15.0

# %%
df.sample(5)
# Out:
#      Manufacturer    Model     Type  Price  MPG.city      AirBags  Horsepower  \
# 43        Hyundai    Excel    Small    8.0        29          NaN          81
# 87     Volkswagen      Fox    Small    9.1        25          NaN          81
# 54          Mazda      626  Compact   16.5        26  Driver only         164
# 30           Ford  Festiva    Small    7.4        31          NaN          63
# 57  Mercedes-Benz     190E  Compact   31.9        20  Driver only         130
#
#     Passengers  Rear.seat.room  Luggage.room
# 43           5            26.0          11.0
# 87           4            26.0          10.0
# 54           5            29.5          14.0
# 30           4            26.0          12.0
# 57           5            26.0          12.0

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Price', 'MPG.city', 'AirBags',
#        'Horsepower', 'Passengers', 'Rear.seat.room', 'Luggage.room'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           34
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Manufacturer      32
# Model             93
# Type               6
# Price             81
# MPG.city          21
# AirBags            2
# Horsepower        57
# Passengers         6
# Rear.seat.room    24
# Luggage.room      16
# dtype: int64
